# %%
from cocube import CoCube

client = CoCube()
found_devices = client.discover(timeout=5)
# Out:
# discovering...

# %%
print(found_devices)
# Out:
# ['MicroBlocks CFH', 'MicroBlocks AZB', 'MicroBlocks QCQ']

# %%
client.connect("MicroBlocks QCQ")
# Out:
# MicroBlocks QCQ is connected

# %%
client.position_x
# Out:
# 1250

# %%
client.position_y
# Out:
# 216

# %%
client.battery
# Out:
# 88

# %%
client.turn_left(10)

# %%
client.motor_stop()

# %%
client.rotate_to_angle??
# Out:
# Signature: client.rotate_to_angle(angle=0, speed=10)
# Docstring: <no docstring>
# Source:
#     def rotate_to_angle(self, angle=0, speed=10):
#         self.request("Rotate to Angle", [angle, speed])
# File:      ~/Documents/MicroBlocks/cocube/src/cocube/__init__.py
# Type:      method

# %%
client.rotate_to_angle(angle=10, speed=20)
